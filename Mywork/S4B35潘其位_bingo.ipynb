# %%
def Bingo():
    
    maxnum = 100
    minnum = 1
    num0 = 0
    num1 = 0
    bingo = 0
    change = 0
    turn = 0
    mun = 0
    word = 0
    again = 0
    bug = 0
    bug2 = 0
    time = 0
    time2 = 0
    helpname = 0
    check = [0]
    name = [0]
    words = [0]
    
    try:
        
        number = int(input('How many people will play? '))
        
    except:
        
        try:
            
            number = int(input('Pleace type in number '))
            
        except:
            
            print('I have given you a chance')
            bingo = 1
        
    while mun < 3 and bingo == 0:
        
        if mun == 2:
            
            print('I have given you a chance')
            break
            
        if number > 10:
            
            print('That is too mach people')
            number = int(input('How many people will play? '))
            mun += 1
            
        elif number < 1:
            
            print('???')
            number = int(input('How many people will play? '))
            mun += 1
            
        elif number >= 1 and number <= 10:
            
            break
            
        else:
            
            if word == 0:
                
                print('Is not fun')
                number = int(input('How many people will play? '))
                word += 1
                
            elif word == 1:
                
                print('Is really not fun, please stop')
                number = int(input('How many people will play? '))
                word += 1
                
            else:
                
                print('I have given you a chance')
                break  
                
    while helpname <= number:
            
        name = name + [0]
        check = check + [0]
        words = words + [0]
        helpname += 1
        
    if number > 1:
        
        for i in range(number):    
            name[i] = input('What is players ' + str(i + 1) + ' \'s name: ')
            
    else:
        
        name[0] = 'your' 
        
    changerange = input('''Do you want to change the range?(now is 1 to 100)
Please say yes or no: ''')
    
    if changerange == 'yes' or changerange == 'Yes':
        
        try:
            
            minnum, maxnum = [int(x) for x in input("Please type min to max: ").split(' to ')]
            
        except:    
            
            try:
                
                minnum, maxnum = [int(x) for x in input("Please type min to max in number: ").split(' to ')]
                
            except:
                
                print('I have given you a chance')
                bingo = 1
                
            else:
                
                print(str(minnum) + ' to ' + str(maxnum))
            
        else:
            
            print(str(minnum) + ' to ' + str(maxnum))
        
    elif changerange == 'no' or changerange == 'No':
        
        print(str(minnum) + ' to ' + str(maxnum))
        
    else:
        
        print('I don\'t know what you\'re talking about')
            
        while time2 < 3:
                
            bug2 = input('Please say yes or no: ')
                
            if bug2 == 'yes' or bug2 == 'Yes':
                    
                Bingo()
                    
            elif bug2 == 'no' or bug2 == 'No':
                    
                print('Thanks for playing')
                    
            else:
                    
                if time2 == 0:
                        
                    print('Is not fun')
                    time2 += 1
                        
                elif time2 == 1:
                        
                    print('Is really not fun, please stop')
                    time2 += 1
                        
                else:
                        
                    print('I have given you a chance')
                    bingo = 1
                    
    import numpy as np
    random = np.random.randint(minnum, maxnum)
        
    while bingo == 0:

        change = 0
        
        if turn < number:
            
            num = input('Is ' + name[turn] + ' turn: ')
            turn += 1
            
        else:
            
            turn = 0
            num = input('Is ' + name[turn] + ' turn: ')
            turn += 1
            
        try:
            
            num = int(num)
            
        except:
            
            if words[turn] < 2:
                
                if words[turn] == 0:

                    num = input('Please type number: ')
                    words[turn] += 1
                    
                    try:
                        
                        num = int(num)
                        
                    except:
                        
                        num = input('This is last chance, please type number: ')
                        words[turn] += 1
                        
                        try:
                            
                            num = int(num)
                            
                        except:
                            
                            print('I have given you a chance')
                            break
                            
                        else:
                        
                            if num <= minnum or num >= maxnum:
            
                                if num == minnum and num1 == 0:
                
                                    num1 = 1
                
                                elif num == maxnum and num0 == 0:
                
                                    num0 = 1
                
                                else:
                
                                    change = 1
                
                                    if check[turn] < 3:
                    
                                        print('Out of range')
                    
                                        if check[turn] == 0:
                        
                                            print('You only have three chance and you just use one')
                                            check[turn] = 1
                        
                                        elif check[turn] == 1:
                        
                                            print('Now you used two')
                                            check[turn] = 2
                        
                                        else:
                        
                                            print('Last chance')
                                            check[turn] = 3
                        
                                        turn -= 1
                    
                                    else:
                    
                                        print('I have given you a chance')
                                        break
                    
                            if num < random and change == 0:
            
                                minnum = num
                                print(str(minnum) + ' to ' + str(maxnum))
            
                            elif num > random and change == 0:
            
                                maxnum = num
                                print(str(minnum) + ' to ' + str(maxnum))
            
                            elif num == random:
            
                                bingo = 1
                                print('BINGO!!!')
                            
                    else:
                        
                        if num <= minnum or num >= maxnum:
            
                            if num == 1 and num1 == 0:
                
                                num1 = 1
                
                            elif num == 100 and num0 == 0:
                
                                num0 = 1
                
                            else:
                
                                change = 1
                
                                if check[turn] < 3:
                    
                                    print('Out of range')
                    
                                    if check[turn] == 0:
                        
                                        print('You only have three chance and you just use one')
                                        check[turn] = 1
                        
                                    elif check[turn] == 1:
                        
                                        print('Now you used two')
                                        check[turn] = 2
                        
                                    else:
                        
                                        print('Last chance')
                                        check[turn] = 3
                        
                                    turn -= 1
                    
                                else:
                    
                                    print('I have given you a chance')
                                    break
                    
                        if num < random and change == 0:
            
                            minnum = num
                            print(str(minnum) + ' to ' + str(maxnum))
            
                        elif num > random and change == 0:
            
                            maxnum = num
                            print(str(minnum) + ' to ' + str(maxnum))
            
                        elif num == random:
            
                            bingo = 1
                            print('BINGO!!!')
                
                elif words[turn] == 1:
                
                    num = input('This is last chance, please type number: ')
                    words[turn] += 1
                
            else:
                
                print('I have given you a chance')
                break  
            
        else:
            
            if num <= minnum or num >= maxnum:
            
                if num == 1 and num1 == 0:
                
                    num1 = 1
                
                elif num == 100 and num0 == 0:
                
                    num0 = 1
                
                else:
                
                    change = 1
                
                    if check[turn] < 3:
                    
                        print('Out of range')
                    
                        if check[turn] == 0:
                        
                            print('You only have three chance and you just use one')
                            check[turn] = 1
                        
                        elif check[turn] == 1:
                        
                            print('Now you used two')
                            check[turn] = 2
                        
                        else:
                        
                            print('Last chance')
                            check[turn] = 3
                        
                        turn -= 1
                    
                    else:
                    
                        print('I have given you a chance')
                        break
                    
            if num < random and change == 0:
            
                minnum = num
                print(str(minnum) + ' to ' + str(maxnum))
            
            elif num > random and change == 0:
            
                maxnum = num
                print(str(minnum) + ' to ' + str(maxnum))
            
            elif num == random:
            
                bingo = 1
                print('BINGO!!!')
        
    again = input('''Want to play again?
Please say yes or no: ''')
        
    if again == 'yes' or again == 'Yes':
            
        Bingo()
            
    elif again == 'no' or again == 'No':
            
        print('Thanks for playing')
            
    else:
            
        print('I don\'t know what you\'re talking about')
            
        while time < 3:
                
            bug = input('Please say yes or no: ')
                
            if bug == 'yes' or bug == 'Yes':
                    
                Bingo()
                    
            elif bug == 'no' or bug == 'No':
                    
                print('Thanks for playing')
                    
            else:
                    
                if time == 0:
                        
                    print('Is not fun')
                    time += 1
                        
                elif time == 1:
                        
                    print('Is really not fun, please stop')
                    time += 1
                        
                else:
                        
                    print('I have given you a chance')
                    break

Bingo()
# Out:
# How many people will play? 1
# Do you want to change the range?(now is 1 to 100)
# Please say yes or no: yes
# Please type min to max: 1 to 1000000
# 1 to 1000000
# Is your turn: 500000
# 1 to 500000
# Is your turn: 100000
# 100000 to 500000
# Is your turn: 150000
# 100000 to 150000
# Is your turn: 120000
# 120000 to 150000
# Is your turn: 1250000
# Out of range
# You only have three chance and you just use one
# Is your turn: 125000
# 125000 to 150000
# Is your turn: 130000
# 130000 to 150000
# Is your turn: 140000
# 140000 to 150000
# Is your turn: 145000
# 140000 to 145000
# Is your turn: 143000
# 143000 to 145000
# Is your turn: 144000
# 143000 to 144000
# Is your turn: 143500
# 143000 to 143500
# Is your turn: 143200
# 143000 to 143200
# Is your turn: 143100
# 143100 to 143200
# Is your turn: 143150
# 143100 to 143150
# Is your turn: 143140
# 143100 to 143140
